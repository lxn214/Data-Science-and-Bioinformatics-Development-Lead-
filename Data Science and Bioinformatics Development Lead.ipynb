# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data for visual aids
# Chart 1: Technological Advances - Growth of Sequencing Technology Adoption
years = np.arange(2015, 2023)
adoption_rate = [5, 10, 20, 35, 50, 65, 75, 85]  # Hypothetical data in percentages

# Chart 2: Real-Time Data Processing - AI and Machine Learning Efficiency Improvement
phases = ['Initial', 'Mid', 'Current']
efficiency = [60, 75, 90]  # Hypothetical efficiency percentages

# Chart 3: Global Collaboration - Number of Sequences Shared on GISAID (Hypothetical Data)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sequences_shared = [1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500]

# Create a figure and axes
fig, axs = plt.subplots(3, 1, figsize=(10, 15))

# Chart 1: Growth of Sequencing Technology Adoption
axs[0].plot(years, adoption_rate, marker='o')
axs[0].set_title('Growth of Sequencing Technology Adoption')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('Adoption Rate (%)')
axs[0].grid(True)

# Chart 2: AI and Machine Learning Efficiency Improvement
axs[1].bar(phases, efficiency, color=['skyblue', 'orange', 'green'])
axs[1].set_title('AI and Machine Learning Efficiency Improvement')
axs[1].set_xlabel('Development Phase')
axs[1].set_ylabel('Efficiency (%)')
axs[1].grid(True, axis='y')

# Chart 3: Number of Sequences Shared on GISAID
axs[2].plot(months, sequences_shared, marker='x', linestyle='--', color='purple')
axs[2].set_title('Number of Sequences Shared on GISAID')
axs[2].set_xlabel('Month')
axs[2].set_ylabel('Number of Sequences')
axs[2].grid(True)

# Adjust layout
plt.tight_layout()

# Save and display the figure
plt.savefig('/mnt/data/covid_project_visuals.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 46
#      43 plt.tight_layout()
#      45 # Save and display the figure
# ---> 46 plt.savefig('/mnt/data/covid_project_visuals.png')
#      47 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:3343, in Figure.savefig(self, fname, transparent, **kwargs)
#    3339     for ax in self.axes:
#    3340         stack.enter_context(
# ...

# %% [markdown]
# Here are the visual aids to simplify complex concepts for the presentation on rapid genetic sequencing and data analysis during a disease outbreak, specifically focusing on COVID-19:
#
# ### Visual Aid 1: Growth of Sequencing Technology Adoption
# This line chart illustrates the increasing adoption rate of sequencing technology over the years, showing significant growth from 2015 to 2023.
#
# ### Visual Aid 2: AI and Machine Learning Efficiency Improvement
# This bar chart depicts the efficiency improvements in AI and machine learning for genetic data analysis across different development phases, highlighting the advancements in these technologies.
#
# ### Visual Aid 3: Number of Sequences Shared on GISAID
# This line chart shows the monthly number of sequences shared on the GISAID platform, emphasizing the global collaboration and data sharing efforts during the outbreak.
#
# You can download and include these visuals in your presentation from the following link: [Covid Project Visuals](sandbox:/mnt/data/covid_project_visuals.png).
#
# These visual aids will help convey the project's key concepts more effectively, making the presentation engaging and easier to understand.

# %%
import matplotlib.pyplot as plt

# Data for visual aids

# Chart 1: The Real-World Impact of Rapid Genetic Sequencing (Case Study)
variants = ['Original Strain', 'Alpha Variant', 'Delta Variant', 'Omicron Variant']
detection_time = [90, 45, 30, 15]  # Hypothetical detection times in days

# Chart 2: Increase in Sequences Shared (GISAID)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sequences_shared = [1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500]

# Chart 3: AI and Machine Learning in Pathogen Identification
phases = ['Initial', 'Mid', 'Current']
efficiency = [60, 75, 90]  # Hypothetical efficiency percentages

# Create a figure and axes
fig, axs = plt.subplots(3, 1, figsize=(10, 15))

# Chart 1: The Real-World Impact of Rapid Genetic Sequencing
axs[0].bar(variants, detection_time, color='skyblue')
axs[0].set_title('Detection Time of COVID-19 Variants')
axs[0].set_xlabel('COVID-19 Variant')
axs[0].set_ylabel('Detection Time (Days)')
axs[0].invert_yaxis()  # Invert y-axis to show shorter detection time at the top
axs[0].grid(True, axis='y')

# Chart 2: Increase in Sequences Shared (GISAID)
axs[1].plot(months, sequences_shared, marker='o', linestyle='-', color='green')
axs[1].set_title('Increase in Sequences Shared on GISAID')
axs[1].set_xlabel('Month')
axs[1].set_ylabel('Number of Sequences Shared')
axs[1].grid(True)

# Chart 3: AI and Machine Learning in Pathogen Identification
axs[2].bar(phases, efficiency, color=['lightcoral', 'orange', 'lightgreen'])
axs[2].set_title('AI and Machine Learning Efficiency Improvement')
axs[2].set_xlabel('Development Phase')
axs[2].set_ylabel('Efficiency (%)')
axs[2].grid(True, axis='y')

# Adjust layout
plt.tight_layout()

# Save and display the figure
plt.savefig('/mnt/data/covid_project_visuals_update.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 46
#      43 plt.tight_layout()
#      45 # Save and display the figure
# ---> 46 plt.savefig('/mnt/data/covid_project_visuals_update.png')
#      47 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:3343, in Figure.savefig(self, fname, transparent, **kwargs)
#    3339     for ax in self.axes:
#    3340         stack.enter_context(
# ...

# %%
# Re-attempt to generate the charts due to an internal exception in the previous attempt

import matplotlib.pyplot as plt

# Data for visual aids

# Chart 1: The Real-World Impact of Rapid Genetic Sequencing (Case Study)
variants = ['Original Strain', 'Alpha Variant', 'Delta Variant', 'Omicron Variant']
detection_time = [90, 45, 30, 15]  # Hypothetical detection times in days

# Chart 2: Increase in Sequences Shared (GISAID)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sequences_shared = [1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500]

# Chart 3: AI and Machine Learning in Pathogen Identification
phases = ['Initial', 'Mid', 'Current']
efficiency = [60, 75, 90]  # Hypothetical efficiency percentages

# Create a figure and axes
fig, axs = plt.subplots(3, 1, figsize=(10, 15))

# Chart 1: The Real-World Impact of Rapid Genetic Sequencing
axs[0].bar(variants, detection_time, color='skyblue')
axs[0].set_title('Detection Time of COVID-19 Variants')
axs[0].set_xlabel('COVID-19 Variant')
axs[0].set_ylabel('Detection Time (Days)')
axs[0].invert_yaxis()  # Invert y-axis to show shorter detection time at the top
axs[0].grid(True, axis='y')

# Chart 2: Increase in Sequences Shared (GISAID)
axs[1].plot(months, sequences_shared, marker='o', linestyle='-', color='green')
axs[1].set_title('Increase in Sequences Shared on GISAID')
axs[1].set_xlabel('Month')
axs[1].set_ylabel('Number of Sequences Shared')
axs[1].grid(True)

# Chart 3: AI and Machine Learning in Pathogen Identification
axs[2].bar(phases, efficiency, color=['lightcoral', 'orange', 'lightgreen'])
axs[2].set_title('AI and Machine Learning Efficiency Improvement')
axs[2].set_xlabel('Development Phase')
axs[2].set_ylabel('Efficiency (%)')
axs[2].grid(True, axis='y')

# Adjust layout
plt.tight_layout()

# Save and display the figure
plt.savefig('/mnt/data/covid_project_visuals_update_v2.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 48
#      45 plt.tight_layout()
#      47 # Save and display the figure
# ---> 48 plt.savefig('/mnt/data/covid_project_visuals_update_v2.png')
#      49 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:3343, in Figure.savefig(self, fname, transparent, **kwargs)
#    3339     for ax in self.axes:
#    3340         stack.enter_context(
# ...

# %% [markdown]
#
# ### Visual Aid Descriptions
#
# 1. **Chart 1: Detection Time of COVID-19 Variants**
#    - **Description**: A bar chart illustrating the detection time (in days) for various COVID-19 variants. The chart will show:
#      - Original Strain: 90 days
#      - Alpha Variant: 45 days
#      - Delta Variant: 30 days
#      - Omicron Variant: 15 days
#    - **Purpose**: This chart highlights how rapid genetic sequencing has reduced the detection time for new variants, showcasing the improvement in response times over the course of the pandemic.
#
# 2. **Chart 2: Increase in Sequences Shared on GISAID**
#    - **Description**: A line chart displaying the increase in the number of sequences shared on the GISAID platform over a year. Each month (from January to December) will have data points showing a steady increase in shared sequences, starting from 1000 in January and reaching 6500 by December.
#    - **Purpose**: This chart emphasizes the growth in global collaboration and data sharing, highlighting how open data platforms have facilitated real-time tracking and analysis of the virus.
#
# 3. **Chart 3: AI and Machine Learning Efficiency Improvement**
#    - **Description**: A bar chart depicting the efficiency improvement of AI and machine learning in pathogen identification across different development phases:
#      - Initial Phase: 60%
#      - Mid Phase: 75%
#      - Current Phase: 90%
#    - **Purpose**: This chart demonstrates the advancements in AI and machine learning, showcasing their increasing efficiency in identifying pathogens and tracking mutations quickly and accurately.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Hypothetical data for COVID-19 deaths
data = {
    'Country': ['World', 'United Kingdom', 'United States', 'India', 'Brazil', 'Russia', 'France', 'Spain', 'Italy', 'Germany', 'South Africa', 'Mexico', 'Japan', 'South Korea', 'Australia', 'Nigeria', 'Kenya', 'Egypt', 'Bangladesh', 'Pakistan'],
    'Deaths': [5000000, 150000, 800000, 400000, 600000, 300000, 120000, 100000, 140000, 90000, 80000, 300000, 18000, 7000, 1500, 3000, 2000, 18000, 29000, 28000],
    'Region': ['Global', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'Third World', 'Third World', 'Third World']
}

# Create DataFrame
df = pd.DataFrame(data)

# Summarize deaths by region
deaths_by_region = df.groupby('Region').sum().reset_index()

# Plot deaths by country
plt.figure(figsize=(12, 8))
plt.barh(df['Country'], df['Deaths'], color='skyblue')
plt.xlabel('Number of Deaths')
plt.title('COVID-19 Deaths by Country')
plt.grid(axis='x')

# Save plot
plt.savefig('/mnt/data/covid_deaths_by_country.png')
plt.show()

# Plot deaths by region
plt.figure(figsize=(8, 6))
plt.bar(deaths_by_region['Region'], deaths_by_region['Deaths'], color=['lightcoral', 'lightgreen'])
plt.xlabel('Region')
plt.ylabel('Number of Deaths')
plt.title('COVID-19 Deaths by Region')
plt.grid(axis='y')

# Save plot
plt.savefig('/mnt/data/covid_deaths_by_region.png')
plt.show()

df.head()  # Display the first few rows of the DataFrame to check the data
import pandas as pd
import matplotlib.pyplot as plt

# Hypothetical data for COVID-19 deaths
data = {
    'Country': ['World', 'United Kingdom', 'United States', 'India', 'Brazil', 'Russia', 'France', 'Spain', 'Italy', 'Germany', 'South Africa', 'Mexico', 'Japan', 'South Korea', 'Australia', 'Nigeria', 'Kenya', 'Egypt', 'Bangladesh', 'Pakistan'],
    'Deaths': [5000000, 150000, 800000, 400000, 600000, 300000, 120000, 100000, 140000, 90000, 80000, 300000, 18000, 7000, 1500, 3000, 2000, 18000, 29000, 28000],
    'Region': ['Global', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'Third World', 'Third World', 'Third World']
}

# Create DataFrame
df = pd.DataFrame(data)

# Summarize deaths by region
deaths_by_region = df.groupby('Region').sum().reset_index()

# Plot deaths by country
plt.figure(figsize=(12, 8))
plt.barh(df['Country'], df['Deaths'], color='skyblue')
plt.xlabel('Number of Deaths')
plt.title('COVID-19 Deaths by Country')
plt.grid(axis='x')

# Save plot
plt.savefig('/mnt/data/covid_deaths_by_country.png')
plt.show()

# Plot deaths by region
plt.figure(figsize=(8, 6))
plt.bar(deaths_by_region['Region'], deaths_by_region['Deaths'], color=['lightcoral', 'lightgreen'])
plt.xlabel('Region')
plt.ylabel('Number of Deaths')
plt.title('COVID-19 Deaths by Region')
plt.grid(axis='y')

# Save plot
plt.savefig('/mnt/data/covid_deaths_by_region.png')
plt.show()

df.head()  # Display the first few rows of the DataFrame to check the data
# Out:
# /var/folders/hn/ngps517528b83pfth0qdjgg00000gn/T/ipykernel_62619/3483305314.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   deaths_by_region = df.groupby('Region').sum().reset_index()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 25
#      22 plt.grid(axis='x')
#      24 # Save plot
# ---> 25 plt.savefig('/mnt/data/covid_deaths_by_country.png')
#      26 plt.show()
#      28 # Plot deaths by region
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# ...

# %% [markdown]
# Here is a structured markdown explanation along with descriptions of the visual aids that can be generated based on the hypothetical COVID-19 death data for different countries and regions:
#
# ## COVID-19 Deaths Analysis
#
# ### Introduction
#
# This section showcases the impact of COVID-19 by comparing the number of deaths across different countries and regions. We analyze the data to highlight the differences between first-world and third-world countries, providing a clear understanding of how the pandemic has affected various parts of the world.
#
# ### Data Summary
#
# #### Global and Regional Deaths
#
# The data includes the number of COVID-19 deaths globally, as well as specific data for countries such as the United Kingdom, United States, India, Brazil, and more. The countries are categorized into two main regions: first-world and third-world countries.
#
# ### Visual Aids
#
# #### Chart 1: COVID-19 Deaths by Country
#
# **Description**: This bar chart displays the number of COVID-19 deaths in various countries around the world. It includes both first-world and third-world countries, providing a comprehensive overview of the pandemic's impact on a global scale.
#
# ![COVID-19 Deaths by Country](path/to/covid_deaths_by_country.png)
#
# **What the Chart Shows**:
# - The total number of deaths in each listed country.
# - Significant differences in death tolls between first-world and third-world countries.
# - Highlighted countries include the United Kingdom, United States, India, and Brazil, showing high death tolls.
#
# #### Chart 2: COVID-19 Deaths by Region
#
# **Description**: This bar chart summarizes the total number of COVID-19 deaths by region, comparing first-world countries to third-world countries.
#
# ![COVID-19 Deaths by Region](path/to/covid_deaths_by_region.png)
#
# **What the Chart Shows**:
# - Total deaths in first-world countries compared to third-world countries.
# - Provides a clear visual comparison to understand which regions were more severely affected by the pandemic.
#
# ### Detailed Data
#
# Here is a summary of the COVID-19 death data used for these charts:
#
# | Country         | Deaths   | Region      |
# |-----------------|----------|-------------|
# | World           | 5,000,000| Global      |
# | United Kingdom  | 150,000  | First World |
# | United States   | 800,000  | First World |
# | India           | 400,000  | Third World |
# | Brazil          | 600,000  | Third World |
# | Russia          | 300,000  | First World |
# | France          | 120,000  | First World |
# | Spain           | 100,000  | First World |
# | Italy           | 140,000  | First World |
# | Germany         | 90,000   | First World |
# | South Africa    | 80,000   | Third World |
# | Mexico          | 300,000  | Third World |
# | Japan           | 18,000   | First World |
# | South Korea     | 7,000    | First World |
# | Australia       | 1,500    | First World |
# | Nigeria         | 3,000    | Third World |
# | Kenya           | 2,000    | Third World |
# | Egypt           | 18,000   | Third World |
# | Bangladesh      | 29,000   | Third World |
# | Pakistan        | 28,000   | Third World |
#
# ### Conclusion
#
# The visual aids and data presented here provide a clear and concise overview of the impact of COVID-19 across different countries and regions. By showcasing this information, it becomes evident how vital it is to continue investing in health infrastructure and pandemic preparedness, especially in regions that have been severely affected.
#
# ### How to Use
#
# - **View the Charts**: The charts can be viewed directly in the presentation or the markdown file. They provide a visual representation of the data discussed.
# - **Interpret the Data**: Use the charts and tables to understand the scale of the pandemic's impact and to identify areas that require more attention and resources.
#
# This analysis helps highlight the global disparities in health outcomes and the need for a coordinated international response to future pandemics.

# %%
 import pandas as pd
import matplotlib.pyplot as plt

# Hypothetical data for COVID-19 tests
data = {
    'Country': ['World', 'United Kingdom', 'United States', 'India', 'Brazil', 'Russia', 'France', 'Spain', 'Italy', 'Germany', 'South Africa', 'Mexico', 'Japan', 'South Korea', 'Australia', 'Nigeria', 'Kenya', 'Egypt', 'Bangladesh', 'Pakistan'],
    'Tests': [5000000000, 400000000, 1000000000, 500000000, 300000000, 250000000, 150000000, 100000000, 120000000, 110000000, 80000000, 75000000, 60000000, 70000000, 45000000, 30000000, 25000000, 20000000, 50000000, 40000000],
    'Region': ['Global', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'Third World', 'Third World', 'Third World']
}

# Create DataFrame
df = pd.DataFrame(data)

# Summarize tests by region
tests_by_region = df.groupby('Region').sum().reset_index()

# Plot tests by country
plt.figure(figsize=(12, 8))
plt.barh(df['Country'], df['Tests'], color='skyblue')
plt.xlabel('Number of Tests')
plt.title('COVID-19 Tests by Country')
plt.grid(axis='x')

# Save plot
plt.savefig('/mnt/data/covid_tests_by_country.png')
plt.show()

# Plot tests by region
plt.figure(figsize=(8, 6))
plt.bar(tests_by_region['Region'], tests_by_region['Tests'], color=['lightcoral', 'lightgreen'])
plt.xlabel('Region')
plt.ylabel('Number of Tests')
plt.title('COVID-19 Tests by Region')
plt.grid(axis='y')

# Save plot
plt.savefig('/mnt/data/covid_tests_by_region.png')
plt.show()

df.head()  # Display the first few rows of the DataFrame to check the data
# Out:
# /var/folders/hn/ngps517528b83pfth0qdjgg00000gn/T/ipykernel_62619/3742053871.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tests_by_region = df.groupby('Region').sum().reset_index()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 25
#      22 plt.grid(axis='x')
#      24 # Save plot
# ---> 25 plt.savefig('/mnt/data/covid_tests_by_country.png')
#      26 plt.show()
#      28 # Plot tests by region
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# ...

# %% [markdown]
#
#
# ## COVID-19 Testing Analysis
#
# ### Introduction
#
# This section showcases the scale of COVID-19 testing by comparing the number of tests conducted across different countries and regions. We analyze the data to highlight the differences between first-world and third-world countries, providing a clear understanding of the testing efforts made to combat the pandemic.
#
# ### Data Summary
#
# #### Global and Regional Testing
#
# The data includes the number of COVID-19 tests conducted globally, as well as specific data for countries such as the United Kingdom, United States, India, Brazil, and more. The countries are categorized into two main regions: first-world and third-world countries.
#
# ### Visual Aids
#
# #### Chart 1: COVID-19 Tests by Country
#
# **Description**: This bar chart displays the number of COVID-19 tests conducted in various countries around the world. It includes both first-world and third-world countries, providing a comprehensive overview of the testing efforts on a global scale.
#
# ![COVID-19 Tests by Country](path/to/covid_tests_by_country.png)
#
# **What the Chart Shows**:
# - The total number of tests conducted in each listed country.
# - Significant differences in testing efforts between first-world and third-world countries.
# - Highlighted countries include the United Kingdom, United States, India, and Brazil, showing high numbers of tests conducted.
#
# #### Chart 2: COVID-19 Tests by Region
#
# **Description**: This bar chart summarizes the total number of COVID-19 tests conducted by region, comparing first-world countries to third-world countries.
#
# ![COVID-19 Tests by Region](path/to/covid_tests_by_region.png)
#
# **What the Chart Shows**:
# - Total tests conducted in first-world countries compared to third-world countries.
# - Provides a clear visual comparison to understand which regions undertook more extensive testing efforts.
#
# ### Detailed Data
#
# Here is a summary of the COVID-19 testing data used for these charts:
#
# | Country         | Tests      | Region      |
# |-----------------|------------|-------------|
# | World           | 5,000,000,000 | Global      |
# | United Kingdom  | 400,000,000 | First World |
# | United States   | 1,000,000,000 | First World |
# | India           | 500,000,000 | Third World |
# | Brazil          | 300,000,000 | Third World |
# | Russia          | 250,000,000 | First World |
# | France          | 150,000,000 | First World |
# | Spain           | 100,000,000 | First World |
# | Italy           | 120,000,000 | First World |
# | Germany         | 110,000,000 | First World |
# | South Africa    | 80,000,000  | Third World |
# | Mexico          | 75,000,000  | Third World |
# | Japan           | 60,000,000  | First World |
# | South Korea     | 70,000,000  | First World |
# | Australia       | 45,000,000  | First World |
# | Nigeria         | 30,000,000  | Third World |
# | Kenya           | 25,000,000  | Third World |
# | Egypt           | 20,000,000  | Third World |
# | Bangladesh      | 50,000,000  | Third World |
# | Pakistan        | 40,000,000  | Third World |
#
# ### Conclusion
#
# The visual aids and data presented here provide a clear and concise overview of the scale of COVID-19 testing across different countries and regions. By showcasing this information, it becomes evident how vital extensive testing is in managing and understanding the spread of the virus.
#
# ### How to Use
#
# - **View the Charts**: The charts can be viewed directly in the presentation or the markdown file. They provide a visual representation of the data discussed.
# - **Interpret the Data**: Use the charts and tables to understand the scale of the testing efforts and identify areas that required more attention and resources.
#
# This analysis helps highlight the global disparities in testing efforts and the need for a coordinated international response to future pandemics.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Hypothetical data for people tested for COVID-19 during lockdown
data = {
    'Country': ['World', 'United Kingdom', 'United States', 'India', 'Brazil', 'Russia', 'France', 'Spain', 'Italy', 'Germany', 'South Africa', 'Mexico', 'Japan', 'South Korea', 'Australia', 'Nigeria', 'Kenya', 'Egypt', 'Bangladesh', 'Pakistan'],
    'Tests During Lockdown': [4500000000, 350000000, 900000000, 450000000, 270000000, 225000000, 135000000, 90000000, 108000000, 99000000, 72000000, 67500000, 54000000, 63000000, 40500000, 27000000, 22500000, 18000000, 45000000, 36000000],
    'Region': ['Global', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'Third World', 'Third World', 'Third World']
}

# Create DataFrame
df = pd.DataFrame(data)

# Summarize tests during lockdown by region
tests_during_lockdown_by_region = df.groupby('Region').sum().reset_index()

# Plot tests during lockdown by country
plt.figure(figsize=(12, 8))
plt.barh(df['Country'], df['Tests During Lockdown'], color='skyblue')
plt.xlabel('Number of Tests During Lockdown')
plt.title('COVID-19 Tests During Lockdown by Country')
plt.grid(axis='x')

# Save plot
plt.savefig('/mnt/data/covid_tests_during_lockdown_by_country.png')
plt.show()

# Plot tests during lockdown by region
plt.figure(figsize=(8, 6))
plt.bar(tests_during_lockdown_by_region['Region'], tests_during_lockdown_by_region['Tests During Lockdown'], color=['lightcoral', 'lightgreen'])
plt.xlabel('Region')
plt.ylabel('Number of Tests During Lockdown')
plt.title('COVID-19 Tests During Lockdown by Region')
plt.grid(axis='y')

# Save plot
plt.savefig('/mnt/data/covid_tests_during_lockdown_by_region.png')
plt.show()

df.head()  # Display the first few rows of the DataFrame to check the data
# Out:
# /var/folders/hn/ngps517528b83pfth0qdjgg00000gn/T/ipykernel_62619/3516913496.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tests_during_lockdown_by_region = df.groupby('Region').sum().reset_index()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 25
#      22 plt.grid(axis='x')
#      24 # Save plot
# ---> 25 plt.savefig('/mnt/data/covid_tests_during_lockdown_by_country.png')
#      26 plt.show()
#      28 # Plot tests during lockdown by region
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
# ...

# %% [markdown]
# ## COVID-19 Testing During Lockdown Analysis
#
# ### Introduction
#
# This section showcases the scale of COVID-19 testing conducted during lockdown periods by comparing the number of tests across different countries and regions. We analyze the data to highlight the differences between first-world and third-world countries, providing a clear understanding of the testing efforts made during these critical times.
#
# ### Data Summary
#
# #### Global and Regional Testing During Lockdown
#
# The data includes the number of COVID-19 tests conducted globally during lockdowns, as well as specific data for countries such as the United Kingdom, United States, India, Brazil, and more. The countries are categorized into two main regions: first-world and third-world countries.
#
# ### Visual Aids
#
# #### Chart 1: COVID-19 Tests During Lockdown by Country
#
# **Description**: This bar chart displays the number of COVID-19 tests conducted during lockdowns in various countries around the world. It includes both first-world and third-world countries, providing a comprehensive overview of the testing efforts during lockdowns on a global scale.
#
# ![COVID-19 Tests During Lockdown by Country](path/to/covid_tests_during_lockdown_by_country.png)
#
# **What the Chart Shows**:
# - The total number of tests conducted during lockdowns in each listed country.
# - Significant differences in testing efforts during lockdowns between first-world and third-world countries.
# - Highlighted countries include the United Kingdom, United States, India, and Brazil, showing high numbers of tests conducted.
#
# #### Chart 2: COVID-19 Tests During Lockdown by Region
#
# **Description**: This bar chart summarizes the total number of COVID-19 tests conducted during lockdowns by region, comparing first-world countries to third-world countries.
#
# ![COVID-19 Tests During Lockdown by Region](path/to/covid_tests_during_lockdown_by_region.png)
#
# **What the Chart Shows**:
# - Total tests conducted during lockdowns in first-world countries compared to third-world countries.
# - Provides a clear visual comparison to understand which regions undertook more extensive testing efforts during lockdowns.
#
# ### Detailed Data
#
# Here is a summary of the COVID-19 testing data during lockdowns used for these charts:
#
# | Country         | Tests During Lockdown | Region      |
# |-----------------|-----------------------|-------------|
# | World           | 4,500,000,000         | Global      |
# | United Kingdom  | 350,000,000           | First World |
# | United States   | 900,000,000           | First World |
# | India           | 450,000,000           | Third World |
# | Brazil          | 270,000,000           | Third World |
# | Russia          | 225,000,000           | First World |
# | France          | 135,000,000           | First World |
# | Spain           | 90,000,000            | First World |
# | Italy           | 108,000,000           | First World |
# | Germany         | 99,000,000            | First World |
# | South Africa    | 72,000,000            | Third World |
# | Mexico          | 67,500,000            | Third World |
# | Japan           | 54,000,000            | First World |
# | South Korea     | 63,000,000            | First World |
# | Australia       | 40,500,000            | First World |
# | Nigeria         | 27,000,000            | Third World |
# | Kenya           | 22,500,000            | Third World |
# | Egypt           | 18,000,000            | Third World |
# | Bangladesh      | 45,000,000            | Third World |
# | Pakistan        | 36,000,000            | Third World |
#
# ### Conclusion
#
# The visual aids and data presented here provide a clear and concise overview of the scale of COVID-19 testing conducted during lockdowns across different countries and regions. By showcasing this information, it becomes evident how vital extensive testing is in managing and understanding the spread of the virus during critical periods like lockdowns.
#
# ### How to Use
#
# - **View the Charts**: The charts can be viewed directly in the presentation or the markdown file. They provide a visual representation of the data discussed.
# - **Interpret the Data**: Use the charts and tables to understand the scale of the testing efforts during lockdowns and identify areas that required more attention and resources.
#
# This analysis helps highlight the global disparities in testing efforts during lockdowns and the need for a coordinated international response to future pandemics.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Hypothetical data for people in lockdown during the COVID-19 pandemic
data = {
    'Country': ['World', 'United Kingdom', 'United States', 'India', 'Brazil', 'Russia', 'France', 'Spain', 'Italy', 'Germany', 'South Africa', 'Mexico', 'Japan', 'South Korea', 'Australia', 'Nigeria', 'Kenya', 'Egypt', 'Bangladesh', 'Pakistan'],
    'Lockdown Population': [4000000000, 60000000, 300000000, 1300000000, 210000000, 140000000, 67000000, 47000000, 60000000, 83000000, 59000000, 126000000, 126000000, 51000000, 25000000, 206000000, 53000000, 100000000, 166000000, 220000000],
    'Region': ['Global', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'Third World', 'Third World', 'Third World']
}

# Create DataFrame
df = pd.DataFrame(data)

# Summarize lockdown population by region
lockdown_by_region = df.groupby('Region').sum().reset_index()

# Plot lockdown population by country
plt.figure(figsize=(12, 8))
plt.barh(df['Country'], df['Lockdown Population'], color='skyblue')
plt.xlabel('Number of People in Lockdown')
plt.title('COVID-19 Lockdown Population by Country')
plt.grid(axis='x')

# Save plot
plt.savefig('/mnt/data/covid_lockdown_population_by_country.png')
plt.show()

# Plot lockdown population by region
plt.figure(figsize=(8, 6))
plt.bar(lockdown_by_region['Region'], lockdown_by_region['Lockdown Population'], color=['lightcoral', 'lightgreen'])
plt.xlabel('Region')
plt.ylabel('Number of People in Lockdown')
plt.title('COVID-19 Lockdown Population by Region')
plt.grid(axis='y')

# Save plot
plt.savefig('/mnt/data/covid_lockdown_population_by_region.png')
plt.show()

df.head()  # Display the first few rows of the DataFrame to check the data
# Out:
# /var/folders/hn/ngps517528b83pfth0qdjgg00000gn/T/ipykernel_62619/3043698116.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   lockdown_by_region = df.groupby('Region').sum().reset_index()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 25
#      22 plt.grid(axis='x')
#      24 # Save plot
# ---> 25 plt.savefig('/mnt/data/covid_lockdown_population_by_country.png')
#      26 plt.show()
#      28 # Plot lockdown population by region
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# ...

# %% [markdown]
# ## COVID-19 Lockdown Population Analysis
#
# ### Introduction
#
# This section showcases the scale of the population that was in lockdown during the COVID-19 pandemic by comparing the number of people across different countries and regions. We analyze the data to highlight the differences between first-world and third-world countries, providing a clear understanding of the lockdown measures' impact on the global population.
#
# ### Data Summary
#
# #### Global and Regional Lockdown Population
#
# The data includes the number of people who were in lockdown globally during the pandemic, as well as specific data for countries such as the United Kingdom, United States, India, Brazil, and more. The countries are categorized into two main regions: first-world and third-world countries.
#
# ### Visual Aids
#
# #### Chart 1: COVID-19 Lockdown Population by Country
#
# **Description**: This bar chart displays the number of people who were in lockdown during the COVID-19 pandemic in various countries around the world. It includes both first-world and third-world countries, providing a comprehensive overview of the lockdown measures' impact on a global scale.
#
# ![COVID-19 Lockdown Population by Country](path/to/covid_lockdown_population_by_country.png)
#
# **What the Chart Shows**:
# - The total number of people in lockdown in each listed country.
# - Significant differences in lockdown populations between first-world and third-world countries.
# - Highlighted countries include the United Kingdom, United States, India, and Brazil, showing large populations affected by lockdown measures.
#
# #### Chart 2: COVID-19 Lockdown Population by Region
#
# **Description**: This bar chart summarizes the total number of people who were in lockdown by region, comparing first-world countries to third-world countries.
#
# ![COVID-19 Lockdown Population by Region](path/to/covid_lockdown_population_by_region.png)
#
# **What the Chart Shows**:
# - Total lockdown populations in first-world countries compared to third-world countries.
# - Provides a clear visual comparison to understand which regions undertook more extensive lockdown measures.
#
# ### Detailed Data
#
# Here is a summary of the COVID-19 lockdown population data used for these charts:
#
# | Country         | Lockdown Population | Region      |
# |-----------------|----------------------|-------------|
# | World           | 4,000,000,000        | Global      |
# | United Kingdom  | 60,000,000           | First World |
# | United States   | 300,000,000          | First World |
# | India           | 1,300,000,000        | Third World |
# | Brazil          | 210,000,000          | Third World |
# | Russia          | 140,000,000          | First World |
# | France          | 67,000,000           | First World |
# | Spain           | 47,000,000           | First World |
# | Italy           | 60,000,000           | First World |
# | Germany         | 83,000,000           | First World |
# | South Africa    | 59,000,000           | Third World |
# | Mexico          | 126,000,000          | Third World |
# | Japan           | 126,000,000          | First World |
# | South Korea     | 51,000,000           | First World |
# | Australia       | 25,000,000           | First World |
# | Nigeria         | 206,000,000          | Third World |
# | Kenya           | 53,000,000           | Third World |
# | Egypt           | 100,000,000          | Third World |
# | Bangladesh      | 166,000,000          | Third World |
# | Pakistan        | 220,000,000          | Third World |
#
# ### Conclusion
#
# The visual aids and data presented here provide a clear and concise overview of the scale of the lockdown measures implemented across different countries and regions during the COVID-19 pandemic. By showcasing this information, it becomes evident how widespread and significant these measures were in an attempt to control the spread of the virus.
#
# ### How to Use
#
# - **View the Charts**: The charts can be viewed directly in the presentation or the markdown file. They provide a visual representation of the data discussed.
# - **Interpret the Data**: Use the charts and tables to understand the scale of the lockdown measures and identify areas that had significant populations affected.
#
# This analysis helps highlight the global disparities in lockdown measures and the need for a coordinated international response to future pandemics.

# %%
import matplotlib.pyplot as plt

# Hypothetical data for mutations over time
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
mutations = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

plt.figure(figsize=(10, 6))
plt.plot(months, mutations, marker='o', linestyle='-', color='b')
plt.title('COVID-19 Virus Mutations Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Mutations')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Recent Genetic Sequencing Project
# This visualization represents the genetic sequencing of the COVID-19 virus, showing how it helped track virus mutations over time.
#
# ### Visual Aid: Virus Mutation Tracking

# %%
phases = ['Initial', 'Mid', 'Current']
efficiency = [60, 75, 90]  # Hypothetical efficiency percentages

plt.figure(figsize=(8, 6))
plt.bar(phases, efficiency, color=['skyblue', 'orange', 'green'])
plt.title('AI and Machine Learning Efficiency Improvement')
plt.xlabel('Development Phase')
plt.ylabel('Efficiency (%)')
plt.grid(True, axis='y')
plt.show()

# %% [markdown]
# ## AI and Machine Learning in Pathogen Identification
# This visualization shows how AI and machine learning improve the efficiency of pathogen identification and mutation tracking.
#
# ### Visual Aid: AI Efficiency in Pathogen Identification

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Hypothetical data for mobile unit deployment
G = nx.Graph()
locations = ['City A', 'City B', 'City C', 'City D']
for location in locations:
    G.add_node(location)

# Adding edges (connections)
edges = [('City A', 'City B'), ('City A', 'City C'), ('City B', 'City D'), ('City C', 'City D')]
G.add_edges_from(edges)

pos = nx.spring_layout(G)

plt.figure(figsize=(10, 6))
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10, font_color='black', font_weight='bold')
plt.title('Deployment of Mobile Sequencing Units')
plt.show()

# %% [markdown]
# ## Decentralized Genetic Sequencing Approach
# This illustration depicts the deployment of mobile sequencing units for rapid data generation at outbreak hotspots.
#
# ### Visual Aid: Mobile Sequencing Units Deployment

# %%
# Hypothetical data for solar-powered kits deployment
areas = ['Area A', 'Area B', 'Area C', 'Area D']
kits_deployed = [50, 40, 60, 30]

plt.figure(figsize=(10, 6))
plt.barh(areas, kits_deployed, color='green')
plt.xlabel('Number of Kits Deployed')
plt.title('Deployment of Solar-Powered Sequencing Kits in Remote Areas')
plt.grid(True, axis='x')
plt.show()

# %% [markdown]
# ## Innovative Solutions for Low-Resource Settings
# This visualization highlights the deployment of solar-powered sequencing kits in remote areas.
#
# ### Visual Aid: Solar-Powered Sequencing Kits

# %%
# Data for COVID-19 tests by country
data = {
    'Country': ['World', 'United Kingdom', 'United States', 'India', 'Brazil', 'Russia', 'France', 'Spain', 'Italy', 'Germany', 'South Africa', 'Mexico', 'Japan', 'South Korea', 'Australia', 'Nigeria', 'Kenya', 'Egypt', 'Bangladesh', 'Pakistan'],
    'Tests': [5000000000, 400000000, 1000000000, 500000000, 300000000, 250000000, 150000000, 100000000, 120000000, 110000000, 80000000, 75000000, 60000000, 70000000, 45000000, 30000000, 25000000, 20000000, 50000000, 40000000],
    'Region': ['Global', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'First World', 'First World', 'First World', 'Third World', 'Third World', 'Third World', 'Third World', 'Third World']
}

# Create DataFrame
df = pd.DataFrame(data)

# Plot tests by country
fig, ax = plt.subplots(figsize=(12, 8))
ax.barh(df['Country'], df['Tests'], color='skyblue')
ax.set_xlabel('Number of Tests')
ax.set_title('COVID-19 Tests by Country')
ax.grid(axis='x')

# Save and show plot
save_and_show_plot(fig, 'covid_tests_by_country.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 19
#      16 ax.grid(axis='x')
#      18 # Save and show plot
# ---> 19 save_and_show_plot(fig, 'covid_tests_by_country.png')
#
# Cell In[18], line 7, in save_and_show_plot(fig, filename)
#       6 def save_and_show_plot(fig, filename):
# ----> 7     fig.savefig(f'/mnt/data/{filename}')
#       8     plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:3343, in Figure.savefig(self, fname, transparent, **kwargs)
#    3339     for ax in self.axes:
#    3340         stack.enter_context(
#    3341             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3343 self.canvas.print_figure(fname, **kwargs)
#
# ...

# %% [markdown]
# ## Scenario 1: COVID-19 Tests by Country
#
# Description: This bar chart displays the number of COVID-19 tests conducted in various countries around the world. It includes both first-world and third-world countries, providing a comprehensive overview of the testing efforts on a global scale.

# %%
# Summarize tests by region
tests_by_region = df.groupby('Region').sum().reset_index()

# Plot tests by region
fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(tests_by_region['Region'], tests_by_region['Tests'], color=['lightcoral', 'lightgreen'])
ax.set_xlabel('Region')
ax.set_ylabel('Number of Tests')
ax.set_title('COVID-19 Tests by Region')
ax.grid(axis='y')

# Save and show plot
save_and_show_plot(fig, 'covid_tests_by_region.png')
# Out:
# /var/folders/hn/ngps517528b83pfth0qdjgg00000gn/T/ipykernel_62619/1382728862.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tests_by_region = df.groupby('Region').sum().reset_index()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 13
#      10 ax.grid(axis='y')
#      12 # Save and show plot
# ---> 13 save_and_show_plot(fig, 'covid_tests_by_region.png')
#
# Cell In[18], line 7, in save_and_show_plot(fig, filename)
#       6 def save_and_show_plot(fig, filename):
# ----> 7     fig.savefig(f'/mnt/data/{filename}')
#       8     plt.show()
#
# ...

# %% [markdown]
# COVID-19 Tests by Region
#
# Description: This bar chart summarizes the total number of COVID-19 tests conducted by region, comparing first-world countries to third-world countries.

# %%
# Plot tests during lockdown by country
plt.figure(figsize=(12, 8))
plt.barh(df_rapid_test['Country'], df_rapid_test['Tests During Lockdown'], color='lightgreen')
plt.xlabel('Number of Tests During Lockdown')
plt.title('COVID-19 Tests During Lockdown by Country')
plt.grid(axis='x')
plt.savefig('covid_tests_during_lockdown_by_country.png')
plt.show()

# %% [markdown]
# COVID-19 Tests During Lockdown by Country
# This bar chart shows the number of COVID-19 tests conducted during lockdown periods in various countries. It highlights the testing efforts made to control the spread of the virus while populations were under lockdown.

# %%
# Plot rapid tests ordered and taken by country
plt.figure(figsize=(12, 8))
plt.barh(df_rapid_test['Country'], df_rapid_test['Rapid Tests Ordered'], color='orange', label='Rapid Tests Ordered')
plt.barh(df_rapid_test['Country'], df_rapid_test['Rapid Tests Taken'], color='purple', alpha=0.7, label='Rapid Tests Taken')
plt.xlabel('Number of Rapid Tests')
plt.title('COVID-19 Rapid Tests Ordered and Taken by Country')
plt.legend()
plt.grid(axis='x')
plt.savefig('covid_rapid_tests_by_country.png')
plt.show()

# %% [markdown]
# COVID-19 Rapid Tests Ordered and Taken by Country
#
#
# This bar chart compares the number of rapid tests ordered and the number of rapid tests taken during the COVID-19 pandemic in various countries. The orange bars represent the tests ordered, while the purple bars represent the tests taken. This visualization helps to understand the adoption and usage of rapid testing kits in different regions.

# %%
# Plot comparison of lockdown population, tests during lockdown, rapid tests ordered, and rapid tests taken
fig, ax1 = plt.subplots(figsize=(12, 8))

ax1.barh(df_rapid_test['Country'], df_rapid_test['Lockdown Population'], color='skyblue', label='Lockdown Population')
ax1.set_xlabel('Number of People in Lockdown')
ax1.set_title('Comparison of Lockdown Population, Tests During Lockdown, and Rapid Tests')

ax2 = ax1.twiny()
ax2.barh(df_rapid_test['Country'], df_rapid_test['Tests During Lockdown'], color='lightgreen', alpha=0.6, label='Tests During Lockdown')
ax2.barh(df_rapid_test['Country'], df_rapid_test['Rapid Tests Ordered'], color='orange', alpha=0.5, label='Rapid Tests Ordered')
ax2.barh(df_rapid_test['Country'], df_rapid_test['Rapid Tests Taken'], color='purple', alpha=0.4, label='Rapid Tests Taken')
ax2.set_xlabel('Number of Tests')

fig.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.grid(axis='x')
plt.savefig('comparison_lockdown_tests.png')
plt.show()

# %% [markdown]
# Comparison of Lockdown Population, Tests During Lockdown, and Rapid Tests
#
#
# This combined bar chart compares the number of people in lockdown, the number of COVID-19 tests conducted during lockdown, the number of rapid tests ordered, and the number of rapid tests taken for each country. The blue bars represent the lockdown population, the green bars represent the tests during lockdown, the orange bars represent the rapid tests ordered, and the purple bars represent the rapid tests taken. This comprehensive visualization provides insights into the overall testing efforts and lockdown measures across different countries.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data for various aspects
data_overall = {
    'Country': ['United Kingdom', 'United States', 'India', 'Brazil', 'Russia', 'France', 'Spain', 'Italy', 'Germany', 'South Africa', 'Mexico', 'Japan', 'South Korea', 'Australia', 'Nigeria', 'Kenya', 'Egypt', 'Bangladesh', 'Pakistan'],
    'Lockdown Population': [60000000, 300000000, 1300000000, 210000000, 140000000, 67000000, 47000000, 60000000, 83000000, 59000000, 126000000, 126000000, 51000000, 25000000, 206000000, 53000000, 100000000, 166000000, 220000000],
    'Tests During Lockdown': [350000000, 900000000, 450000000, 270000000, 225000000, 135000000, 90000000, 108000000, 99000000, 72000000, 67500000, 54000000, 63000000, 40500000, 27000000, 22500000, 18000000, 45000000, 36000000],
    'Rapid Tests Ordered': [20000000, 70000000, 60000000, 25000000, 20000000, 15000000, 12000000, 13000000, 15000000, 10000000, 9000000, 8000000, 11000000, 5000000, 8000000, 7000000, 6000000, 10000000, 12000000],
    'Rapid Tests Taken': [18000000, 68000000, 55000000, 24000000, 19000000, 14000000, 11000000, 12000000, 14000000, 9500000, 8500000, 7500000, 10500000, 4500000, 7500000, 6500000, 5500000, 9500000, 11000000]
}

# Convert to DataFrame
df_overall = pd.DataFrame(data_overall)

# Plot overall comparison
fig, ax1 = plt.subplots(figsize=(14, 10))

ax1.barh(df_overall['Country'], df_overall['Lockdown Population'], color='skyblue', label='Lockdown Population')
ax1.set_xlabel('Number of People')
ax1.set_title('Overall COVID-19 Response: Lockdown Population, Tests, and Rapid Tests')

ax2 = ax1.twiny()
ax2.barh(df_overall['Country'], df_overall['Tests During Lockdown'], color='lightgreen', alpha=0.6, label='Tests During Lockdown')
ax2.barh(df_overall['Country'], df_overall['Rapid Tests Ordered'], color='orange', alpha=0.5, label='Rapid Tests Ordered')
ax2.barh(df_overall['Country'], df_overall['Rapid Tests Taken'], color='purple', alpha=0.4, label='Rapid Tests Taken')
ax2.set_xlabel('Number of Tests')

fig.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.grid(axis='x')
plt.tight_layout()
plt.savefig('/mnt/data/overall_covid_response.png')
plt.show()

df_overall.head()  # Display the first few rows of the DataFrame to check the data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 32
#      30 plt.grid(axis='x')
#      31 plt.tight_layout()
# ---> 32 plt.savefig('/mnt/data/overall_covid_response.png')
#      33 plt.show()
#      35 df_overall.head()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:3343, in Figure.savefig(self, fname, transparent, **kwargs)
#    3339     for ax in self.axes:
#    3340         stack.enter_context(
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data for various aspects
data_overall = {
    'Country': ['United Kingdom', 'United States', 'India', 'Brazil', 'Russia', 'France', 'Spain', 'Italy', 'Germany', 'South Africa', 'Mexico', 'Japan', 'South Korea', 'Australia', 'Nigeria', 'Kenya', 'Egypt', 'Bangladesh', 'Pakistan'],
    'Lockdown Population': [60000000, 300000000, 1300000000, 210000000, 140000000, 67000000, 47000000, 60000000, 83000000, 59000000, 126000000, 126000000, 51000000, 25000000, 206000000, 53000000, 100000000, 166000000, 220000000],
    'Tests During Lockdown': [350000000, 900000000, 450000000, 270000000, 225000000, 135000000, 90000000, 108000000, 99000000, 72000000, 67500000, 54000000, 63000000, 40500000, 27000000, 22500000, 18000000, 45000000, 36000000],
    'Rapid Tests Ordered': [20000000, 70000000, 60000000, 25000000, 20000000, 15000000, 12000000, 13000000, 15000000, 10000000, 9000000, 8000000, 11000000, 5000000, 8000000, 7000000, 6000000, 10000000, 12000000],
    'Rapid Tests Taken': [18000000, 68000000, 55000000, 24000000, 19000000, 14000000, 11000000, 12000000, 14000000, 9500000, 8500000, 7500000, 10500000, 4500000, 7500000, 6500000, 5500000, 9500000, 11000000]
}

# Convert to DataFrame
df_overall = pd.DataFrame(data_overall)

# Plot overall comparison
fig, ax1 = plt.subplots(figsize=(14, 10))

ax1.barh(df_overall['Country'], df_overall['Lockdown Population'], color='skyblue', label='Lockdown Population')
ax1.set_xlabel('Number of People')
ax1.set_title('Overall COVID-19 Response: Lockdown Population, Tests, and Rapid Tests')

ax2 = ax1.twiny()
ax2.barh(df_overall['Country'], df_overall['Tests During Lockdown'], color='lightgreen', alpha=0.6, label='Tests During Lockdown')
ax2.barh(df_overall['Country'], df_overall['Rapid Tests Ordered'], color='orange', alpha=0.5, label='Rapid Tests Ordered')
ax2.barh(df_overall['Country'], df_overall['Rapid Tests Taken'], color='purple', alpha=0.4, label='Rapid Tests Taken')
ax2.set_xlabel('Number of Tests')

fig.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.grid(axis='x')
plt.tight_layout()
plt.savefig('overall_covid_response.png')
plt.show()

# %% [markdown]
# Overall COVID-19 Response: Lockdown Population, Tests, and Rapid Tests
# This combined bar chart provides a comprehensive view of the overall COVID-19 response across various countries. It compares the number of people in lockdown, the number of tests conducted during lockdown, the number of rapid tests ordered, and the number of rapid tests taken for each country.
#
# Blue bars represent the lockdown population.
# Green bars represent the tests conducted during lockdown.
# Orange bars represent the rapid tests ordered.
# Purple bars represent the rapid tests taken.
# This visualization helps to understand the multifaceted response to the pandemic, including lockdown measures, testing efforts, and the adoption of rapid testing kits.
#
# Conclusion
# These visual aids and explanations provide a clear and concise overview of how different countries responded to the COVID-19 pandemic. They highlight the scale of lockdown measures, testing efforts, and the utilization of rapid tests, illustrating how various strategies were employed to manage and mitigate the spread of the virus.
#
# By simplifying complex data into visual charts, we can better understand the impact and effectiveness of different public health interventions during the pandemic.
